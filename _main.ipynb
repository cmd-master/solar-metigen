# %% [markdown]
# # Summary
# Goal:
# To explore the Solar output a PV system.
#
# Reference:
# - [Data Source](https://www.kaggle.com/datasets/fvcoppen/solarpanelspower)
# - [Kaggle](https://www.kaggle.com/code/fiftythirtyfour/solar-panels-power/notebook)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('input/metingen_27feb2022.csv'
                 , names=['date', 'cum_sol', 'kwh_day', 'gas_day']
                , parse_dates=[0], dayfirst=True, skiprows=1
                )
df.head()
# Out:
#         date  cum_sol  kwh_day  gas_day
# 0 2011-10-26      0.1     15.1      9.0
# 1 2011-10-27     10.2      7.4      9.2
# 2 2011-10-28     20.2      5.8      8.0
# 3 2011-10-29     29.6      4.9      6.6
# 4 2011-10-30     34.2     11.7      5.3

# %%
df.groupby('date')['kwh_day'].sum().plot()
# Out:
# <Axes: xlabel='date'>

# %%
df['date']
# Out:
# 0      2011-10-26
# 1      2011-10-27
# 2      2011-10-28
# 3      2011-10-29
# 4      2011-10-30
#           ...
# 3837   2022-04-28
# 3838   2022-04-29
# 3839   2022-04-30
# 3840   2022-05-01
# 3841   2022-05-02
# Name: date, Length: 3842, dtype: datetime64[ns]
